# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
# ...

# %%
# %cd /content/drive/MyDrive/yolov7
#!git clone https://github.com/augmentedstartups/yolov7.git
# Out:
# /content/drive/MyDrive/yolov7

# %%
# %cd /content/drive/MyDrive/yolov7/yolov7
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/yolov7
#!mkdir train_data
# %cd train_data
# !unzip /content/drive/MyDrive/yolov7/train_data/Data.zip
# Out:
# /content/drive/MyDrive/yolov7
# /content/drive/MyDrive/yolov7/train_data
# Archive:  /content/drive/MyDrive/yolov7/train_data/Data.zip
#  extracting: Data/08iht-reho08-slide-slide-TAEU-jumbo.txt
#   inflating: Data/0f339af3af0bd3a3e69180ffe756b63a.jpg
#   inflating: Data/0f339af3af0bd3a3e69180ffe756b63a.txt
#   inflating: Data/11q.jpg
#   inflating: Data/11q.txt
#   inflating: Data/1491445762643.jpg
#   inflating: Data/1491445762643.txt
#   inflating: Data/1540_image006.jpg
#   inflating: Data/1540_image006.txt
#   inflating: Data/1633891259101_Toyota Premio G Superior 2018 for sale.jpg
#   inflating: Data/1633891259101_Toyota Premio G Superior 2018 for sale.txt
#   inflating: Data/1633891259871_Toyota Allion 260 2007 for sale.jpg
#   inflating: Data/1633891259871_Toyota Allion 260 2007 for sale.txt
#   inflating: Data/1633891260040_DFSK IAuto 2021 for sale.jpg
#   inflating: Data/1633891260040_DFSK IAuto 2021 for sale.txt
# ...

# %%
# %cd /content/drive/MyDrive/yolov7/yolov7
# !mkdir pretrain
# Out:
# /content/drive/MyDrive/yolov7/yolov7

# %%
# %cd /content/drive/MyDrive/yolov7/train_data/Data
# !mkdir train
# !mkdir train/labels
# !mkdir train/images
# !mv *.jpeg train/images
# !mv *.jfif train/images
# !mv *.jpg train/images
# !mv *.png train/images
# !mv *.txt train/labels
# Out:
# /content/drive/MyDrive/yolov7/train_data/Data

# %%
# %cd /content/drive/MyDrive/yolov7/yolov7
# !rm data/mydataset.yaml # nếu có
# !echo 'train: ../train_data/Data/train' >> data/mydataset.yaml
# !echo 'val: ../train_data/Data/train' >> data/mydataset.yaml
# !echo 'nc: 6' >> data/mydataset.yaml
# !echo "names: ['Motorbike','Car','Walker','Bike','Truck','Bus']" >> data/mydataset.yaml
# Out:
# /content/drive/MyDrive/yolov7/yolov7

# %%
# %cd /content/drive/MyDrive/yolov7/yolov7
# !python train.py --batch 8 --cfg cfg/training/yolov7.yaml --epochs 50 --data data/mydataset.yaml --weights '/content/drive/MyDrive/yolov7/yolov7/runs/train/exp15/weights/last.pt'
# Out:
# /content/drive/MyDrive/yolov7/yolov7
# 2023-04-04 13:49:27.067505: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 13:49:27.911063: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-104-g941b94c torch 2.0.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov7/yolov7/runs/train/exp16/weights/best.pt --source /content/drive/MyDrive/yolov7/train_data/test/test5.png
# Out:
# python3: can't open file '/content/detect.py': [Errno 2] No such file or directory

# %%
from IPython.display import Image,display
display(Image(filename="/content/drive/MyDrive/yolov7/yolov7/runs/detect/exp8/1.jpg"))
